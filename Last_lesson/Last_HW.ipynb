# %% [markdown]
# ### Problem 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
boston = load_boston()

x = pd.DataFrame(boston.data, columns = boston.feature_names)
y = boston.target

# %% [markdown]
# Разбейте эти датафреймы на тренировочные (X_train, y_train) и тестовые (X_test, y_test)
# с помощью функции train_test_split так, чтобы размер тестовой выборки
# составлял 20% от всех данных, при этом аргумент random_state должен быть равен 42.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=42)
print(X_train)
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 477  15.02340   0.0  18.10   0.0  0.6140  5.304  97.3  2.1007  24.0  666.0
# 15    0.62739   0.0   8.14   0.0  0.5380  5.834  56.5  4.4986   4.0  307.0
# 332   0.03466  35.0   6.06   0.0  0.4379  6.031  23.3  6.6407   1.0  304.0
# 423   7.05042   0.0  18.10   0.0  0.6140  6.103  85.1  2.0218  24.0  666.0
# 19    0.72580   0.0   8.14   0.0  0.5380  5.727  69.5  3.7965   4.0  307.0
# ..        ...   ...    ...   ...     ...    ...   ...     ...   ...    ...
# 106   0.17120   0.0   8.56   0.0  0.5200  5.836  91.9  2.2110   5.0  384.0
# 270   0.29916  20.0   6.96   0.0  0.4640  5.856  42.1  4.4290   3.0  223.0
# 348   0.01501  80.0   2.01   0.0  0.4350  6.635  29.7  8.3440   4.0  280.0
# 435  11.16040   0.0  18.10   0.0  0.7400  6.629  94.6  2.1247  24.0  666.0
# 102   0.22876   0.0   8.56   0.0  0.5200  6.405  85.4  2.7147   5.0  384.0
#
#      PTRATIO       B  LSTAT
# 477     20.2  349.48  24.91
# ...

# %% [markdown]
# Масштабируйте данные с помощью StandardScaler.

# %%
scaler = StandardScaler(with_mean=False)

X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.fit_transform(X_test), columns=X_test.columns)
print(X_train_scaled)

plt.scatter(X_train_scaled['ZN'], Y_train)
plt.title('Scaled Data Train')
plt.show()
plt.scatter(X_test_scaled['ZN'], Y_test)
plt.title('Scaled Data Test')
plt.show()
# Out:
#          CRIM        ZN     INDUS  CHAS       NOX        RM       AGE  \
# 0    1.694865  0.000000  2.628491   0.0  5.222922  7.485465  3.479940
# 1    0.070779  0.000000  1.182095   0.0  4.576437  8.233447  2.020726
# 2    0.003910  1.513591  0.880036   0.0  3.724947  8.511471  0.833326
# 3    0.795393  0.000000  2.628491   0.0  5.222922  8.613084  3.043606
# 4    0.081881  0.000000  1.182095   0.0  4.576437  8.082440  2.485671
# ..        ...       ...       ...   ...       ...       ...       ...
# 399  0.019314  0.000000  1.243088   0.0  4.423322  8.236270  3.286809
# 400  0.033750  0.864909  1.010735   0.0  3.946964  8.264496  1.505709
# 401  0.001693  3.459638  0.291893   0.0  3.700279  9.363888  1.062222
# 402  1.259061  0.000000  2.628491   0.0  6.294727  9.355420  3.383374
# 403  0.025808  0.000000  1.243088   0.0  4.423322  9.039292  3.054336
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %% [markdown]
# Постройте модель TSNE на тренировочный данных с параметрами:
# n_components=2, learning_rate=250, random_state=42.
#
# Постройте диаграмму рассеяния на этих данных.

# %%
from sklearn.manifold import TSNE
from sklearn.datasets import load_boston

# %%
tsne = TSNE(n_components=2, learning_rate=250, random_state=42)
X_train_tsne = tsne.fit_transform(X_train_scaled)
print(X_train_tsne)
# Out:
# [[ 28.13809     18.375324  ]
#  [ -9.785578    -4.5355387 ]
#  [-15.695753   -17.543627  ]
#  [ 37.924854    13.517046  ]
#  [ -8.786393     3.9951665 ]
#  [-13.988173    -7.7626657 ]
#  [-11.960751    -7.4771976 ]
#  [-18.704308   -23.812914  ]
#  [ 38.665813    12.55771   ]
#  [ 35.53426     11.327715  ]
#  [-12.056245    -8.116859  ]
#  [ -5.7400675   -5.8184624 ]
#  [ -2.0275154   -8.284211  ]
#  [ 35.76188     12.485169  ]
#  [ -2.2966845  -10.11944   ]
#  [-10.227566     7.138571  ]
#  [ -7.261146     1.1323055 ]
#  [-14.401978   -18.217144  ]
#  [-13.338248   -12.094605  ]
#  [-17.165924   -12.843067  ]
#  [ 34.02783     17.060034  ]
#  [ -4.4231987    0.22272195]
#  [-15.497815    -7.9093003 ]
#  [-10.733389    -5.5205164 ]
#  [-18.339699   -23.839216  ]
#  [ -3.087924    -8.492775  ]
#  [  8.2998       2.3935862 ]
#  [ -1.5845332  -12.5177965 ]
#  [ -1.7503096   13.745355  ]
#  [-17.836658    -8.000917  ]
#  [ -8.456023     7.1432576 ]
#  [ -3.9704554    1.7679943 ]
# ...

# %%
plt.scatter(X_train_tsne[:, 0], X_train_tsne[:, 1])

plt.show()

# %% [markdown]
# ### Problem 2

# %% [markdown]
# С помощью KMeans разбейте данные из тренировочного набора на 3 кластера,
# используйте все признаки из датафрейма X_train.
# Параметр max_iter должен быть равен 100, random_state сделайте равным 42.

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=3, random_state=42, max_iter = 100)
Y_train_2 = pd.DataFrame(Y_train,columns=['Y'])

# %%
train_labels_1 = model.fit_predict(X_train)

# %%
tsne = TSNE(n_components=2, learning_rate=250, random_state=42)
X_train_tsne = tsne.fit_transform(X_train_scaled)
plt.scatter(X_train_tsne[:, 0], X_train_tsne[:, 1], c=train_labels_1)
plt.show()

# %%
model.inertia_
# Out:
# 2534884.8524944647

# %% [markdown]
# ### Better solution:

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1, random_state=42)

X_train_mc = pca.fit_transform(X_train)
X_valid_mc = pca.transform(X_test)
pca.explained_variance_ratio_
# Out:
# array([0.80082761])

# %%
Y_train_2 = pd.DataFrame(Y_train,columns=['Y'])
X_train_mc_df = pd.DataFrame(X_train_mc,columns=['X'])
data=pd.concat([X_train_mc_df, Y_train_2],  axis=1, join='inner')
print(data)
data.info()

model_2 = KMeans(n_clusters=3, random_state=42, max_iter = 100)
train_labels_2 = model_2.fit_predict(data)
plt.scatter(data['X'], data['Y'], c=train_labels_2)
plt.show()
# Out:
#               X     Y
# 0    254.616285  12.0
# 1   -104.689342  19.9
# 2   -101.902093  19.4
# 3    356.963242  13.4
# 4   -102.198771  18.2
# ..          ...   ...
# 399  -28.632873  19.5
# 400 -184.199995  21.1
# 401 -134.609518  24.5
# 402  325.790975  13.4
# 403   67.663047  18.6
#
# [404 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       404 non-null    float64
#  1   Y       404 non-null    float64
# dtypes: float64(2)
# memory usage: 6.4 KB

# %%
model_2.inertia_
# Out:
# 623445.3243667072

# %% [markdown]
# Постройте еще раз диаграмму рассеяния на данных, полученных с помощью TSNE,
# и раскрасьте точки из разных кластеров разными цветами.
# Вычислите средние значения price и CRIM в разных кластерах.

# %%
tsne = TSNE(n_components=2, learning_rate=250, random_state=42)
X_train_tsne = tsne.fit_transform(X_train_scaled)
plt.scatter(X_train_tsne[:, 0], X_train_tsne[:, 1], c=train_labels_2)
plt.show()

# %%
X_train_clust = pd.concat([X_train.sort_index(),pd.DataFrame({'CLUSTER' : [*train_labels_2],'price' : [*Y_train]})], axis=1)
X_stat = X_train_clust.groupby('CLUSTER').agg({'CRIM':['mean'],'price':['mean']})
print(X_stat)
# Out:
#              CRIM      price
#              mean       mean
# CLUSTER
# 0.0      1.408196  26.143925
# 1.0      1.407191  16.225000
# 2.0      3.752500  22.413953

# %% [markdown]
# ### Problem 3

# %%
test_lables = model_2.fit_predict(X_test)

# %%
X_test_clust = pd.concat([X_test.sort_index(),pd.DataFrame({'CLUSTER' : [*test_lables],'price' : [*Y_test]})], axis=1)
X_stat = X_test_clust.groupby('CLUSTER').agg({'CRIM':['mean'],'price':['mean']})
print(X_stat)
# Out:
#              CRIM      price
#              mean       mean
# CLUSTER
# 0.0      0.246694  23.911594
# 1.0      0.196386  17.392308
# 2.0      0.128160  12.814286
